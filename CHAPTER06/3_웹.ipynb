# %%
import pandas as pd
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'BUG: DataFrameGroupBy.transform with axis=1 fails'

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    36308  BUG: DataFrameGroupBy.transform with axis=1 fails
# 1    36307  TYPING: `df.columns.levels` raises mypy error ...
# 2    36306  BUG: DataFrameGroupBy.apply with as_index Fals...
# 3    36305  ENH: Support MultiIndex columns in parquet (#3...
# 4    36304  PERF: creating string Series/Arrays from seque...
# 5    36303        REGR: Fix IntegerArray unary ops regression
# 6    36302  BUG: DataFrameGroupBy.__getitem__ should warn ...
# 7    36301                      REF: de-duplicate sort_values
# 8    36300                      [DOC]: Improve drop isin docs
# 9    36299  [BUG]: Index.union() inconsisten with non-uniq...
# 10   36298  Py39 Support - Remove Deprecated Unicode Lengt...
# 11   36297  BUG: fix duplicate entries in LaTeX List of Ta...
# 12   36296                                BLD/CI: 3.9 support
# 13   36295                        CLN: Remove trailing commas
# 14   36294  BUG:unexpected behavior of pandas 1.1.1 dt.nor...
# 15   36293  BUG: `DataFrame.drop` fails when there is a mu...
# 16   36291  BUG: pandas series creation fails with Overflo...
# 17   36290  [BUG]: Fix ValueError in concat() when at leas...
# 18   36289  BUG: Index.union() drops Index component for d...
# 19   36288   ERR: Report key on (unsupported) indexing errors
# 20   36287  ENH: support of pandas.DataFrame.hist for date...
# 21   36286  ENH: allow sort_values to use the natural sort...
# 22   36284       DOC: Fixed type hints for GroupBy.{any, all}
# 23   36283  TST: #31922 assert no segmentation fault with ...
# 24   36282               REF: de-duplicate _wrap_joined_index
# 25   36281                QST: Appending to pandas DataFrames
# 26   36280                      PERF: CategoricalDtype.__eq__
# 27   36279                      QST: Python 3.9 testing in CI
# 28   36278                          [TST]: Add test for 24768
# 29   36277                             ENH: add peek function
#
#                                                labels state
# 0   [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 1                                                  []  open
# 2   [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 3                                                  []  open
# 4                                                  []  open
# 5   [{'id': 1817503692, 'node_id': 'MDU6TGFiZWwxOD...  open
# 6   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 7                                                  []  open
# 8                                                  []  open
# 9                                                  []  open
# 10                                                 []  open
# 11                                                 []  open
# 12  [{'id': 129350, 'node_id': 'MDU6TGFiZWwxMjkzNT...  open
# 13  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 14  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 15  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 16  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 17                                                 []  open
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 19  [{'id': 42670965, 'node_id': 'MDU6TGFiZWw0MjY3...  open
# 20                                                 []  open
# 21  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 22                                                 []  open
# 23  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 24                                                 []  open
# 25  [{'id': 34444536, 'node_id': 'MDU6TGFiZWwzNDQ0...  open
# 26                                                 []  open
# 27  [{'id': 717120670, 'node_id': 'MDU6TGFiZWw3MTc...  open
# 28  [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 29  [{'id': 219960758, 'node_id': 'MDU6TGFiZWwyMTk...  open
